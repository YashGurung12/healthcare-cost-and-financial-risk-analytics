# %% [markdown]
# ## MySQL Import Wizard Compatibility
# ### Data csv format conversion to utf8 without BOM

# %%
import pandas as pd

# Read the original CSV
df = pd.read_csv("patients (1).csv")

#saving it without BOM format
df.to_csv("/Users/yashgurung/LearnBay/Projects/List of Projects/YashGurung/Patient-Encounter-Cost-Risk-Analysis/data/raw/patients.csv",
index=False,encoding="utf-8")
df.shape
# Out:
# (974, 20)

# %%
import pandas as pd
df = pd.read_csv("encounters (1).csv")

#saving it without BOM format
df.to_csv("/Users/yashgurung/LearnBay/Projects/List of Projects/YashGurung/Patient-Encounter-Cost-Risk-Analysis/data/raw/encounters.csv",
    index=False,encoding="utf-8")
df.shape
# Out:
# (27891, 14)

# %%
df = pd.read_csv("procedures (2).csv")

#saving it without BOM format
df.to_csv("/Users/yashgurung/LearnBay/Projects/List of Projects/YashGurung/Patient-Encounter-Cost-Risk-Analysis/data/raw/procedures.csv",
    index=False,encoding="utf-8")
df.shape
# Out:
# (47701, 9)

# %%
df = pd.read_csv("organizations (2).csv")

#saving it without BOM format
df.to_csv("/Users/yashgurung/LearnBay/Projects/List of Projects/YashGurung/Patient-Encounter-Cost-Risk-Analysis/data/raw/organizations.csv",
    index=False,encoding="utf-8")
df.shape
# Out:
# (1, 8)

# %%
df = pd.read_csv("payers (1).csv")

#saving it without BOM format
df.to_csv("/Users/yashgurung/LearnBay/Projects/List of Projects/YashGurung/Patient-Encounter-Cost-Risk-Analysis/data/raw/payers.csv",
    index=False,encoding="utf-8")
df.shape
# Out:
# (10, 7)
